# %%
import numpy as np

# %%
theta = 10

# %%
2*np.cos(theta-2*np.pi)
# Out:
# -1.6781430581529047

# %%
2*np.sin(theta)
# Out:
# -1.0880422217787395

# %%
theta1 = 12

# %%
2*np.cos(theta1-2*np.pi)-2*np.cos(theta-2*np.pi)
# Out:
# 3.3658509756178892

# %%
2*np.sin(theta1)-2*np.sin(theta)
# Out:
# 0.01489638577786967

# %%
(10-2*np.pi)*180/np.pi
# Out:
# 212.95779513082323

# %%
(12-2*np.pi)*180/np.pi
# Out:
# 327.5493541569879

# %%
t = np.sqrt(12/9.81)
t
# Out:
# 1.106002527218662

# %%
phi = np.arctan2(10,(9.81*t))*180/np.pi
phi
# Out:
# 42.665796746019531

# %%
deltaT = 135 - phi
deltaT
# Out:
# 92.334203253980462

# %%
omega = deltaT / t * np.pi/180
omega
# Out:
# 1.4570815340180616

# %%
.5**2/4/4
# Out:
# 0.015625

# %%
y0 = 0.5
lambda1 = np.pi/4

# %%
def vx(x):
    return 2/(np.sqrt(1 + y0**2*lambda1**2*np.cos(lambda1*x)**2))

def vy(x):
    return (2*np.cos(lambda1*x))/(np.sqrt(1 + y0**2*lambda1**2*np.cos(lambda1*x)**2))

# %%
t = np.linspace(0,30,200)

# %%
x = np.zeros_like(t)
y = np.zeros_like(t)

# %%
for i in range(1,len(t)):
    x[i] = x[i-1] + vx(x[i-1])*(t[1])
    y[i] = y[i-1] + vy(x[i-1])*(t[1])

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
plt.figure()
plt.plot(x,y)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(t,x)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(t,y)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import sympy as sym
sym.init_printing()

# %%
x = sym.symbols('x')
f = sym.sqrt(1+0.5**2*sym.pi**2/16*sym.cos(sym.pi/4*x)**2)
f
# Out:
#     ___________________________
#    ╱           2    2⎛π⋅x⎞
#   ╱  0.015625⋅π ⋅cos ⎜───⎟ + 1
# ╲╱                   ⎝ 4 ⎠

# %%
I = sym.integrate(f,x)

# %%
I
# Out:
#     ⌠
#     ⎮     _____________________________
#     ⎮    ╱           2    2⎛π⋅x⎞
# 1.0⋅⎮   ╱  0.015625⋅π ⋅cos ⎜───⎟ + 1.0  dx
#     ⎮ ╲╱                   ⎝ 4 ⎠
#     ⌡
